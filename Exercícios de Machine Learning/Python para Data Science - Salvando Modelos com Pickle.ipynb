# %% [markdown]
# ## Importando as bibliotecas básicas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importando o dataset

# %%
dados = pd.read_excel(r'datasets/Data_Train.xlsx')

# %% [markdown]
# Este dataset tem diversos dados de voos com seu preço associado &nbsp;
#
# O objetivo do problema é conseguir prever o preço de um voo através dos dados disponíveis

# %% [markdown]
# ## Olhando para os dados

# %%
dados
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
dados.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
dados.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# Temos muitas colunas categóricas neste dataset, então vamos tentar quebrar algumas, de forma a construir algumas variáveis numéricas

# %% [markdown]
# ## Tratamento dos dados

# %% [markdown]
# ### Quebrando a variável de data

# %%
dados['day'] = pd.Series()
dados['month'] = pd.Series()
dados['year'] = pd.Series()

from datetime import datetime 

for i in dados.index:
    
    dados['day'][i] = datetime.strptime(dados['Date_of_Journey'][i], '%d/%m/%Y').day
    dados['month'][i] = datetime.strptime(dados['Date_of_Journey'][i], '%d/%m/%Y').month
    dados['year'][i] = datetime.strptime(dados['Date_of_Journey'][i], '%d/%m/%Y').year
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\1493554391.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['day'] = pd.Series()
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\1493554391.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['month'] = pd.Series()
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\1493554391.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['year'] = pd.Series()
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\1493554391.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['day'][i] = datetime.strptime(dados['Date_of_Journey'][i], '%d/%m/%Y').day
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\1493554391.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['month'][i] = datetime.strptime(dados['Date_of_Journey'][i], '%d/%m/%Y').month
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\1493554391.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['year'][i] = datetime.strptime(dados['Date_of_Journey'][i], '%d/%m/%Y').year

# %%
dados
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price   day  month    year
# 0             No info   3897  24.0    3.0  2019.0
# 1             No info   7662   1.0    5.0  2019.0
# 2             No info  13882   9.0    6.0  2019.0
# 3             No info   6218  12.0    5.0  2019.0
# 4             No info  13302   1.0    3.0  2019.0
# ...               ...    ...   ...    ...     ...
# 10678         No info   4107   9.0    4.0  2019.0
# 10679         No info   4145  27.0    4.0  2019.0
# 10680         No info   7229  27.0    4.0  2019.0
# 10681         No info  12648   1.0    3.0  2019.0
# 10682         No info  11753   9.0    5.0  2019.0
#
# [10683 rows x 14 columns]

# %%
dados = dados.drop('Date_of_Journey', axis=1)

# %% [markdown]
# ## Quebrando a variável de Hora (Partida e Chegada)

# %%
dados['departure_hour'] = pd.Series()
dados['departure_min'] = pd.Series()
dados['arrival_hour'] = pd.Series()
dados['arrival_min'] = pd.Series()

for i in dados.index:
    
    dados['departure_hour'][i] = int(dados['Dep_Time'][i][0:2])
    dados['departure_min'][i] = int(dados['Dep_Time'][i][3:6])
    dados['arrival_hour'][i] = int(dados['Arrival_Time'][i][0:2])
    dados['arrival_min'][i] = int(dados['Arrival_Time'][i][3:6])
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\2203698733.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['departure_hour'] = pd.Series()
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\2203698733.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['departure_min'] = pd.Series()
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\2203698733.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['arrival_hour'] = pd.Series()
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\2203698733.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['arrival_min'] = pd.Series()
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\2203698733.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['departure_hour'][i] = int(dados['Dep_Time'][i][0:2])
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\2203698733.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['departure_min'][i] = int(dados['Dep_Time'][i][3:6])
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\2203698733.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['arrival_hour'][i] = int(dados['Arrival_Time'][i][0:2])
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\2203698733.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['arrival_min'][i] = int(dados['Arrival_Time'][i][3:6])

# %%
dados
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price   day  month  \
# 0      01:10 22 Mar   2h 50m    non-stop         No info   3897  24.0    3.0
# 1             13:15   7h 25m     2 stops         No info   7662   1.0    5.0
# 2      04:25 10 Jun      19h     2 stops         No info  13882   9.0    6.0
# 3             23:30   5h 25m      1 stop         No info   6218  12.0    5.0
# 4             21:35   4h 45m      1 stop         No info  13302   1.0    3.0
# ...             ...      ...         ...             ...    ...   ...    ...
# 10678         22:25   2h 30m    non-stop         No info   4107   9.0    4.0
# 10679         23:20   2h 35m    non-stop         No info   4145  27.0    4.0
# 10680         11:20       3h    non-stop         No info   7229  27.0    4.0
# 10681         14:10   2h 40m    non-stop         No info  12648   1.0    3.0
# 10682         19:15   8h 20m     2 stops         No info  11753   9.0    5.0
#
#          year  departure_hour  departure_min  arrival_hour  arrival_min
# 0      2019.0            22.0           20.0           1.0         10.0
# 1      2019.0             5.0           50.0          13.0         15.0
# 2      2019.0             9.0           25.0           4.0         25.0
# 3      2019.0            18.0            5.0          23.0         30.0
# 4      2019.0            16.0           50.0          21.0         35.0
# ...       ...             ...            ...           ...          ...
# 10678  2019.0            19.0           55.0          22.0         25.0
# 10679  2019.0            20.0           45.0          23.0         20.0
# 10680  2019.0             8.0           20.0          11.0         20.0
# 10681  2019.0            11.0           30.0          14.0         10.0
# 10682  2019.0            10.0           55.0          19.0         15.0
#
# [10683 rows x 17 columns]

# %%
dados = dados.drop(['Dep_Time', 'Arrival_Time'], axis=1)

# %%
dados
# Out:
#            Airline    Source Destination                  Route Duration  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR   2h 30m
# 10679    Air India   Kolkata    Banglore              CCU → BLR   2h 35m
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL       3h
# 10681      Vistara  Banglore   New Delhi              BLR → DEL   2h 40m
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK   8h 20m
#
#       Total_Stops Additional_Info  Price   day  month    year  departure_hour  \
# 0        non-stop         No info   3897  24.0    3.0  2019.0            22.0
# 1         2 stops         No info   7662   1.0    5.0  2019.0             5.0
# 2         2 stops         No info  13882   9.0    6.0  2019.0             9.0
# 3          1 stop         No info   6218  12.0    5.0  2019.0            18.0
# 4          1 stop         No info  13302   1.0    3.0  2019.0            16.0
# ...           ...             ...    ...   ...    ...     ...             ...
# 10678    non-stop         No info   4107   9.0    4.0  2019.0            19.0
# 10679    non-stop         No info   4145  27.0    4.0  2019.0            20.0
# 10680    non-stop         No info   7229  27.0    4.0  2019.0             8.0
# 10681    non-stop         No info  12648   1.0    3.0  2019.0            11.0
# 10682     2 stops         No info  11753   9.0    5.0  2019.0            10.0
#
#        departure_min  arrival_hour  arrival_min
# 0               20.0           1.0         10.0
# 1               50.0          13.0         15.0
# 2               25.0           4.0         25.0
# 3                5.0          23.0         30.0
# 4               50.0          21.0         35.0
# ...              ...           ...          ...
# 10678           55.0          22.0         25.0
# 10679           45.0          23.0         20.0
# 10680           20.0          11.0         20.0
# 10681           30.0          14.0         10.0
# 10682           55.0          19.0         15.0
#
# [10683 rows x 15 columns]

# %% [markdown]
# Agora que temos algumas variáveis novas na nossa base de dados, vamos tratar as variáveis categóricas

# %% [markdown]
# ## Tratando a variável de quantidade de paradas

# %%
dados['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
dados['Total_Stops'] = dados['Total_Stops'].fillna('non-stop')
dados['stops'] = pd.Series()

for i in dados.index:
    if dados['Total_Stops'][i] == 'non-stop':
        dados.stops[i] = 0
    else:
        dados.stops[i] = int(dados['Total_Stops'][i][0:2])
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\3778945786.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['stops'] = pd.Series()
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\3778945786.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.stops[i] = 0
# C:\Users\andre\AppData\Local\Temp\ipykernel_22408\3778945786.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.stops[i] = int(dados['Total_Stops'][i][0:2])

# %%
dados
# Out:
#            Airline    Source Destination                  Route Duration  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR   2h 30m
# 10679    Air India   Kolkata    Banglore              CCU → BLR   2h 35m
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL       3h
# 10681      Vistara  Banglore   New Delhi              BLR → DEL   2h 40m
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK   8h 20m
#
#       Total_Stops Additional_Info  Price   day  month    year  departure_hour  \
# 0        non-stop         No info   3897  24.0    3.0  2019.0            22.0
# 1         2 stops         No info   7662   1.0    5.0  2019.0             5.0
# 2         2 stops         No info  13882   9.0    6.0  2019.0             9.0
# 3          1 stop         No info   6218  12.0    5.0  2019.0            18.0
# 4          1 stop         No info  13302   1.0    3.0  2019.0            16.0
# ...           ...             ...    ...   ...    ...     ...             ...
# 10678    non-stop         No info   4107   9.0    4.0  2019.0            19.0
# 10679    non-stop         No info   4145  27.0    4.0  2019.0            20.0
# 10680    non-stop         No info   7229  27.0    4.0  2019.0             8.0
# 10681    non-stop         No info  12648   1.0    3.0  2019.0            11.0
# 10682     2 stops         No info  11753   9.0    5.0  2019.0            10.0
#
#        departure_min  arrival_hour  arrival_min  stops
# 0               20.0           1.0         10.0    0.0
# 1               50.0          13.0         15.0    2.0
# 2               25.0           4.0         25.0    2.0
# 3                5.0          23.0         30.0    1.0
# 4               50.0          21.0         35.0    1.0
# ...              ...           ...          ...    ...
# 10678           55.0          22.0         25.0    0.0
# 10679           45.0          23.0         20.0    0.0
# 10680           20.0          11.0         20.0    0.0
# 10681           30.0          14.0         10.0    0.0
# 10682           55.0          19.0         15.0    2.0
#
# [10683 rows x 16 columns]

# %%
dados = dados.drop('Total_Stops', axis=1)

# %% [markdown]
# ## Aplicando o Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

colunas = dados.dtypes.reset_index()

categ_cols = colunas[colunas[0] == 'object']['index'].to_list()

# Preenchendo as variáveis com dados nulos com a média

for i in categ_cols:
    dados[str(i) + '_encoded'] = le.fit_transform(dados[i])
    dados = dados.drop(i, axis=1)

# %%
dados
# Out:
#        Price   day  month    year  departure_hour  departure_min  \
# 0       3897  24.0    3.0  2019.0            22.0           20.0
# 1       7662   1.0    5.0  2019.0             5.0           50.0
# 2      13882   9.0    6.0  2019.0             9.0           25.0
# 3       6218  12.0    5.0  2019.0            18.0            5.0
# 4      13302   1.0    3.0  2019.0            16.0           50.0
# ...      ...   ...    ...     ...             ...            ...
# 10678   4107   9.0    4.0  2019.0            19.0           55.0
# 10679   4145  27.0    4.0  2019.0            20.0           45.0
# 10680   7229  27.0    4.0  2019.0             8.0           20.0
# 10681  12648   1.0    3.0  2019.0            11.0           30.0
# 10682  11753   9.0    5.0  2019.0            10.0           55.0
#
#        arrival_hour  arrival_min  stops  Airline_encoded  Source_encoded  \
# 0               1.0         10.0    0.0                3               0
# 1              13.0         15.0    2.0                1               3
# 2               4.0         25.0    2.0                4               2
# 3              23.0         30.0    1.0                3               3
# 4              21.0         35.0    1.0                3               0
# ...             ...          ...    ...              ...             ...
# 10678          22.0         25.0    0.0                0               3
# 10679          23.0         20.0    0.0                1               3
# 10680          11.0         20.0    0.0                4               0
# 10681          14.0         10.0    0.0               10               0
# 10682          19.0         15.0    2.0                1               2
#
#        Destination_encoded  Route_encoded  Duration_encoded  \
# 0                        5             18               240
# 1                        0             84               336
# 2                        1            118               106
# 3                        0             91               311
# 4                        5             29               303
# ...                    ...            ...               ...
# 10678                    0             64               236
# 10679                    0             64               237
# 10680                    2             18               280
# 10681                    5             18               238
# 10682                    1            108               347
#
#        Additional_Info_encoded
# 0                            8
# 1                            8
# 2                            8
# 3                            8
# 4                            8
# ...                        ...
# 10678                        8
# 10679                        8
# 10680                        8
# 10681                        8
# 10682                        8
#
# [10683 rows x 15 columns]

# %% [markdown]
# ## Quebrando o dataset para modelagem

# %%
from sklearn.model_selection import train_test_split

x = dados.drop('Price', axis=1)
y = dados['Price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Carregando o modelo
# ##### O xgboost e o lightgbm precisam ser instalados caso não tenham sido

# %%
#!pip install xgboost

# %%
#!pip install lightgbm

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score

import time

modelo_gr = GradientBoostingRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)
modelo_xb = XGBRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)
modelo_lg = LGBMRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)

print('============ Gradient Boosting ============')

start = time.time()
modelo_gr.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_gr.predict(x_train)
y_pred_test = modelo_gr.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))

print('============ XG Boost ============')

start = time.time()
modelo_xb.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_xb.predict(x_train)
y_pred_test = modelo_xb.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))

print('============ LGBM ============')

start = time.time()
modelo_lg.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_lg.predict(x_train)
y_pred_test = modelo_lg.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))
# Out:
# ============ Gradient Boosting ============
# O resultado na base de treino é:  0.9348709064319582
# O resultado na base de teste é:  0.8934368046644536
# O tempo que o modelo demorou para treinar foi:  1.1684863567352295
# ============ XG Boost ============
# [16:48:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_leaf_nodes" } are not used.
#
# O resultado na base de treino é:  0.9957181114160927
# O resultado na base de teste é:  0.901175584154553
# O tempo que o modelo demorou para treinar foi:  1.7482366561889648
# ============ LGBM ============
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=20 will be ignored. Current value: num_leaves=31
# O resultado na base de treino é:  0.9207649743039796
# O resultado na base de teste é:  0.8791508906116997
# O tempo que o modelo demorou para treinar foi:  0.11900138854980469

# %% [markdown]
# ## Fazendo a Feature Selection

# %% [markdown]
# ### Select KBest

# %%
from sklearn.feature_selection import SelectKBest, f_regression

# %%
selector = SelectKBest(score_func=f_regression, k = 7)

# Passamos todo o dataframe para a feature selection, não apenas os dados de treino
dados_selected = selector.fit_transform(x, y)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:289: RuntimeWarning: divide by zero encountered in true_divide
#   correlation_coefficient /= X_norms
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:358: RuntimeWarning: invalid value encountered in true_divide
#   f_statistic = corr_coef_squared / (1 - corr_coef_squared) * deg_of_freedom

# %%
dados_selected
# Out:
# array([[ 24.,   3.,  10., ...,   5.,  18., 240.],
#        [  1.,   5.,  15., ...,   0.,  84., 336.],
#        [  9.,   6.,  25., ...,   1., 118., 106.],
#        ...,
#        [ 27.,   4.,  20., ...,   2.,  18., 280.],
#        [  1.,   3.,  10., ...,   5.,  18., 238.],
#        [  9.,   5.,  15., ...,   1., 108., 347.]])

# %%
cols = selector.get_support(indices=True)
cols
# Out:
# array([ 0,  1,  6,  7, 10, 11, 12], dtype=int64)

# %%
dados_new_best = x.iloc[:, cols]
dados_new_best
# Out:
#         day  month  arrival_min  stops  Destination_encoded  Route_encoded  \
# 0      24.0    3.0         10.0    0.0                    5             18
# 1       1.0    5.0         15.0    2.0                    0             84
# 2       9.0    6.0         25.0    2.0                    1            118
# 3      12.0    5.0         30.0    1.0                    0             91
# 4       1.0    3.0         35.0    1.0                    5             29
# ...     ...    ...          ...    ...                  ...            ...
# 10678   9.0    4.0         25.0    0.0                    0             64
# 10679  27.0    4.0         20.0    0.0                    0             64
# 10680  27.0    4.0         20.0    0.0                    2             18
# 10681   1.0    3.0         10.0    0.0                    5             18
# 10682   9.0    5.0         15.0    2.0                    1            108
#
#        Duration_encoded
# 0                   240
# 1                   336
# 2                   106
# 3                   311
# 4                   303
# ...                 ...
# 10678               236
# 10679               237
# 10680               280
# 10681               238
# 10682               347
#
# [10683 rows x 7 columns]

# %% [markdown]
# Essas são as 7 colunas (features) que mais influeciam no preço das passagens

# %% [markdown]
# ### Select Percentile

# %%
from sklearn.feature_selection import SelectPercentile, f_regression

selector = SelectPercentile(score_func=f_regression, percentile=50)
dados_selected = selector.fit_transform(x, y)

cols = selector.get_support(indices=True)
dados_new_percentile = x.iloc[:, cols]
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:289: RuntimeWarning: divide by zero encountered in true_divide
#   correlation_coefficient /= X_norms
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:358: RuntimeWarning: invalid value encountered in true_divide
#   f_statistic = corr_coef_squared / (1 - corr_coef_squared) * deg_of_freedom

# %%
dados_new_percentile
# Out:
#         day  month  arrival_min  stops  Destination_encoded  Route_encoded  \
# 0      24.0    3.0         10.0    0.0                    5             18
# 1       1.0    5.0         15.0    2.0                    0             84
# 2       9.0    6.0         25.0    2.0                    1            118
# 3      12.0    5.0         30.0    1.0                    0             91
# 4       1.0    3.0         35.0    1.0                    5             29
# ...     ...    ...          ...    ...                  ...            ...
# 10678   9.0    4.0         25.0    0.0                    0             64
# 10679  27.0    4.0         20.0    0.0                    0             64
# 10680  27.0    4.0         20.0    0.0                    2             18
# 10681   1.0    3.0         10.0    0.0                    5             18
# 10682   9.0    5.0         15.0    2.0                    1            108
#
#        Duration_encoded
# 0                   240
# 1                   336
# 2                   106
# 3                   311
# 4                   303
# ...                 ...
# 10678               236
# 10679               237
# 10680               280
# 10681               238
# 10682               347
#
# [10683 rows x 7 columns]

# %% [markdown]
# ## Rodando novamente os modelos com a Feature Selection realizada

# %% [markdown]
# ### Select KBest

# %%
x_train, x_test, y_train, y_test = train_test_split(dados_new_best, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score

import time

modelo_gr = GradientBoostingRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)
modelo_xb = XGBRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)
modelo_lg = LGBMRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)

print('============ Gradient Boosting ============')

start = time.time()
modelo_gr.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_gr.predict(x_train)
y_pred_test = modelo_gr.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))

print('============ XG Boost ============')

start = time.time()
modelo_xb.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_xb.predict(x_train)
y_pred_test = modelo_xb.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))

print('============ LGBM ============')

start = time.time()
modelo_lg.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_lg.predict(x_train)
y_pred_test = modelo_lg.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))
# Out:
# ============ Gradient Boosting ============
# O resultado na base de treino é:  0.8491028168273105
# O resultado na base de teste é:  0.7251419119722786
# O tempo que o modelo demorou para treinar foi:  0.6429314613342285
# ============ XG Boost ============
# [16:49:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_leaf_nodes" } are not used.
#
# O resultado na base de treino é:  0.9593375515119554
# O resultado na base de teste é:  0.6864197496260348
# O tempo que o modelo demorou para treinar foi:  0.4579966068267822
# ============ LGBM ============
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=20 will be ignored. Current value: num_leaves=31
# O resultado na base de treino é:  0.8250323469851006
# O resultado na base de teste é:  0.763937131129601
# O tempo que o modelo demorou para treinar foi:  0.12600278854370117

# %% [markdown]
# ### Select Percentile

# %%
x_train, x_test, y_train, y_test = train_test_split(dados_new_percentile, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score

import time

modelo_gr = GradientBoostingRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)
modelo_xb = XGBRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)
modelo_lg = LGBMRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)

print('============ Gradient Boosting ============')

start = time.time()
modelo_gr.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_gr.predict(x_train)
y_pred_test = modelo_gr.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))

print('============ XG Boost ============')

start = time.time()
modelo_xb.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_xb.predict(x_train)
y_pred_test = modelo_xb.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))

print('============ LGBM ============')

start = time.time()
modelo_lg.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_lg.predict(x_train)
y_pred_test = modelo_lg.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))
# Out:
# ============ Gradient Boosting ============
# O resultado na base de treino é:  0.8491028168273105
# O resultado na base de teste é:  0.7251419119722786
# O tempo que o modelo demorou para treinar foi:  0.6396613121032715
# ============ XG Boost ============
# [16:49:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "max_leaf_nodes" } are not used.
#
# O resultado na base de treino é:  0.9593375515119554
# O resultado na base de teste é:  0.6864197496260348
# O tempo que o modelo demorou para treinar foi:  0.4189603328704834
# ============ LGBM ============
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=20 will be ignored. Current value: num_leaves=31
# O resultado na base de treino é:  0.8250323469851006
# O resultado na base de teste é:  0.763937131129601
# O tempo que o modelo demorou para treinar foi:  0.10700321197509766

# %% [markdown]
# ## Conclusão sobre a Feature Selection

# %% [raw]
# Fazer a feature selection não necessariamente vai melhorar os resultados do modelo.
# Isso vai depender da situação analisada.
#
# Se eu tenho variáveis altamente correlacionadas, a feature selection pode ser interessante.
# O mesmo se aplica para datasets com muitas colunas.
#
# Como não é o nosso caso, o resultado dos nossos modelos caiu, sendo mais interessante manter o dataset inteiro, sem feature selection

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# Pegando o modelo inicial que performou melhor, vamos testar fazer o cross validation

# %%
from sklearn.model_selection import train_test_split

x = dados.drop('Price', axis=1)
y = dados['Price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

modelo_gb = GradientBoostingRegressor(max_depth=10, max_leaf_nodes=20, random_state=42)

print('============ Gradient Boosting ============')

start = time.time()
modelo_gb.fit(x_train, y_train)
end = time.time()
y_pred_train = modelo_gb.predict(x_train)
y_pred_test = modelo_gb.predict(x_test)

print('O resultado na base de treino é: ', r2_score(y_train, y_pred_train))
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
print('O tempo que o modelo demorou para treinar foi: ', str(end - start))
# Out:
# ============ Gradient Boosting ============
# O resultado na base de treino é:  0.9348709064319582
# O resultado na base de teste é:  0.8934368046644536
# O tempo que o modelo demorou para treinar foi:  1.0567944049835205

# %%
from sklearn.model_selection import GridSearchCV

parametros = {'n_estimators':[10, 50, 100],
             'learning_rate':[0.1, 1, 10],
             'max_depth':[10, 50, 500],
             'max_leaf_nodes':[10, 50, 100]}

grid = GridSearchCV(estimator = modelo_gb,
                   param_grid  = parametros,
                   cv = 5,
                   scoring = 'r2')

grid.fit(x, y)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:978: RuntimeWarning: overflow encountered in square
#   (array - array_means[:, np.newaxis]) ** 2, axis=1, weights=weights
# GridSearchCV(cv=5,
#              estimator=GradientBoostingRegressor(max_depth=10,
#                                                  max_leaf_nodes=20,
#                                                  random_state=42),
#              param_grid={'learning_rate': [0.1, 1, 10],
#                          'max_depth': [10, 50, 500],
#                          'max_leaf_nodes': [10, 50, 100],
#                          'n_estimators': [10, 50, 100]},
#              scoring='r2')

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 10,
#  'max_leaf_nodes': 50,
#  'n_estimators': 100}

# %%
grid.best_score_
# Out:
# 0.8980487155678606

# %%
melhor_modelo = grid.best_estimator_

# %% [markdown]
# ## Salvando nosso Modelo

# %%
import pickle 

arquivo_modelo = 'modelo.sav' #Poderia ser também o diretório onde eu quero salvar o arquivo

pickle.dump(melhor_modelo, open(arquivo_modelo, 'wb'))

# %% [markdown]
# ## Carregando o Modelo salvo

# %%
modelo_carregado = pickle.load(open(arquivo_modelo, 'rb'))

# %% [markdown]
# ## Código novo que roda todos os dias

# %%
# Importação das bibliotecas
# Tratamento dos dados
# Feature Selection se aplicável
# Carregamento do modelo já treinado
# Previsão e disponibilização dos dados novos já com previsão

# %%
y_pred_test = modelo_carregado.predict(x_test)
print('O resultado na base de teste é: ', r2_score(y_test, y_pred_test))
# Out:
# O resultado na base de teste é:  0.9615088308521905
